# %%
red = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv"
white = "https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
redData = pd.read_csv(red, sep = ";")
whiteData = pd.read_csv(white, sep = ";")

# %%
redData["type"] = 0
whiteData["type"] = 1

# %%
wine = whiteData.append(redData, ignore_index=True)

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x = wine.iloc[:, :12].values
y = wine.iloc[:, 12].values

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
scaller = StandardScaler()
x = scaller.fit_transform(x)

# %%
trainX, testX, trainY, testY = train_test_split(x,y, test_size = 0.3)

# %%
trainY
# Out:
# array([1, 1, 1, ..., 0, 1, 1], dtype=int64)

# %%
#### Deep Learning Part...

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.3.1'

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model = Sequential()
model.add(Dense(20, activation = "relu", input_shape = (12,)))

### OutPut Layer -----
model.add(Dense(1, activation = "sigmoid"))

## Select your Op and Compile Your Model...
model.compile(loss="binary_crossentropy", optimizer = "adam", metrics=["accuracy"])
h = model.fit(trainX, trainY, validation_split=0.3, epochs=30, batch_size = 3000)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 0s 75ms/step - loss: 0.8761 - accuracy: 0.3831 - val_loss: 0.8766 - val_accuracy: 0.3875
# Epoch 2/30
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8560 - accuracy: 0.4060 - val_loss: 0.8565 - val_accuracy: 0.4059
# Epoch 3/30
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8365 - accuracy: 0.4274 - val_loss: 0.8369 - val_accuracy: 0.4249
# Epoch 4/30
# 2/2 [==============================] - 0s 13ms/step - loss: 0.8173 - accuracy: 0.4488 - val_loss: 0.8176 - val_accuracy: 0.4440
# Epoch 5/30
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7986 - accuracy: 0.4683 - val_loss: 0.7988 - val_accuracy: 0.4667
# Epoch 6/30
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7803 - accuracy: 0.4827 - val_loss: 0.7804 - val_accuracy: 0.4799
# Epoch 7/30
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7624 - accuracy: 0.4997 - val_loss: 0.7624 - val_accuracy: 0.4982
# ...

# %%
h.history
# Out:
# {'loss': [0.876122772693634,
#   0.8560347557067871,
#   0.8364946246147156,
#   0.8173359036445618,
#   0.7986140847206116,
#   0.7802842855453491,
#   0.7623870372772217,
#   0.7448558807373047,
#   0.727712869644165,
#   0.7109997272491455,
#   0.6947203874588013,
#   0.6788367629051208,
#   0.6633575558662415,
#   0.6482424736022949,
#   0.6335193514823914,
#   0.619168221950531,
#   0.6052019000053406,
#   0.5916176438331604,
#   0.5783745646476746,
#   0.5655239224433899,
#   0.5530230402946472,
#   0.540799081325531,
#   0.5289570689201355,
#   0.5172895789146423,
#   0.5059981942176819,
#   0.49495065212249756,
#   0.4842455983161926,
#   0.47382888197898865,
#   0.4637182652950287,
#   0.4538916349411011],
#  'accuracy': [0.38309240341186523,
#   0.4060339331626892,
#   0.42740413546562195,
#   0.4487743675708771,
#   0.46825894713401794,
#   0.48271527886390686,
#   0.49968573451042175,
#   0.5172847509384155,
#   0.5336266756057739,
#   0.5524827241897583,
# ...

# %%
loss = h.history["loss"]
acc = h.history["accuracy"]
val_loss = h.history["val_loss"]
val_acc = h.history["val_accuracy"]

# %%
tvA = pd.DataFrame({
    "Ta":acc,
    "Va":val_acc
})

# %%
tvA.boxplot()
plt.show()
